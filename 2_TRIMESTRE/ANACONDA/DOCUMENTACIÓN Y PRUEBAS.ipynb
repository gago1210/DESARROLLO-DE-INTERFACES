# %% [markdown]
# ### DOCSTRINGS

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
def hola(nombre):
    """
        Argumento de cadena de texto, para composición de mensaje al usuario
        controlar posibles datos númericos.
    """
    print("Buenos días",nombre,"!!!")

# %%
hola("Pedro")
# Out:
# Buenos días Pedro !!!

# %%
help(hola)
# Out:
# Help on function hola in module __main__:
#
# hola(nombre)
#     Argumento de cadena de texto, para composición de mensaje al usuario
#     controlar posibles datos númericos.

# %%
class objeto:
    """ Aqui explico la función de la clase y el porque de su uso """
    
    def __init__(self):
        """ Aqui explicamos el código que se ejecuta al instanciar esta clase en un objeto """
        
    def metodo(self):
        """ Fundiones del método y recogida de parametros e instancias con dichos parametros o atributos """

# %%
obj1 = objeto()

# %%
help(objeto)
# Out:
# Help on class objeto in module __main__:
#
# class objeto(builtins.object)
#  |  Aqui explico la función de la clase y el porque de su uso
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Aqui explicamos el código que se ejecuta al instanciar esta clase en un objeto
#  |
#  |  metodo(self)
#  |      Fundiones del método y recogida de parametros e instancias con dichos parametros o atributos
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(obj1)
# Out:
# Help on objeto in module __main__ object:
#
# class objeto(builtins.object)
#  |  Aqui explico la función de la clase y el porque de su uso
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self)
#  |      Aqui explicamos el código que se ejecuta al instanciar esta clase en un objeto
#  |
#  |  metodo(self)
#  |      Fundiones del método y recogida de parametros e instancias con dichos parametros o atributos
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
import saludos

# %%
help(saludos)
# Out:
# Help on module saludos:
#
# NAME
#     saludos - Explicación módulo y los metodos asociados o funciones
#
# FUNCTIONS
#     despedir()
#         Docstring de la función despedir
#
#     saludar()
#         Este es el comentario referente a la función saludar
#
# FILE
#     c:\users\antares\documents\saludos.py

# %%
help(saludos.despedir)
# Out:
# Help on function despedir in module saludos:
#
# despedir()
#     Docstring de la función despedir

# %%
help(saludos.saludar)
# Out:
# Help on function saludar in module saludos:
#
# saludar()
#     Este es el comentario referente a la función saludar

# %%
dir(saludos)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'despedir',
#  'saludar']

# %%
saludos.__name__
# Out:
# 'saludos'

# %%
saludos.__package__
# Out:
# ''

# %%
saludos.__doc__
# Out:
# '\n    Explicación módulo y los metodos asociados o funciones\n'

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
import datetime

# %%
help(datetime)
# Out:
# Help on module datetime:
#
# NAME
#     datetime - Fast implementation of the datetime type.
#
# MODULE REFERENCE
#     https://docs.python.org/3.9/library/datetime
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         date
#             datetime
#         time
#         timedelta
#         tzinfo
#             timezone
#
#     class date(builtins.object)
#      |  date(year, month, day) --> date object
#      |
#      |  Methods defined here:
#      |
#      |  __add__(self, value, /)
#      |      Return self+value.
#      |
#      |  __eq__(self, value, /)
#      |      Return self==value.
#      |
#      |  __format__(...)
# ...

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
help(set)
# Out:
# Help on class set in module builtins:
#
# class set(object)
#  |  set() -> new empty set object
#  |  set(iterable) -> new set object
#  |
#  |  Build an unordered collection of unique elements.
#  |
#  |  Methods defined here:
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
#  |  __contains__(...)
#  |      x.__contains__(y) <==> y in x.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iand__(self, value, /)
#  |      Return self&=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __isub__(self, value, /)
#  |      Return self-=value.
#  |
#  |  __iter__(self, /)
# ...

# %%
import pydoc
import saludos

# %%
pydoc saludos.py
# Out:
#   Input In [34]
#     pydoc saludos.py
#           ^
# SyntaxError: invalid syntax

# %%
python -m pydoc mi_script.py

# %%
pydoc -w saludos.py
# Out:
#   Input In [35]
#     pydoc -w saludos.py
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Epydoc y Sphinx

# %% [markdown]
# ### Doctest - Documenta y test de funcionamiento

# %%
def suma(a,b):
    """ Esta función usa dos parametros, que alimentar con los argumentos adecuados """
    return a+b

# %%
import doctest

# %%
def suma(a,b):
    """ Esta función usa dos parametros, que alimentar con los argumentos adecuados
    >>> suma(6,10)
    """
    return a+b

# %% [markdown]
# ### UNITTEST - PyUNIT

# %%
import unittest
